# %% [markdown]
# # Ödev — ML - Regression — Insurance Charges
#
# **Hedef:** `charges` (sayısal tahmin)
# **Kapsam:** Baseline, Linear Regression, metrikler, residual yorumu
# **Veri:** insurance.csv

# %% [markdown]
# ## Kurulum

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 140)
sns.set_theme()

print("Hazır!")

# %% [markdown]
# ## 1) Veri yükle

# %%
df = pd.read_csv('insurance.csv')
df.head()

# %% [markdown]
# ## 2) ÖDEV GÖREVLERİ

# %% [markdown]
# ### Görev-1 — X/y ve split
# 1) X = charges hariç tüm kolonlar
# 2) y = charges
# 3) Train/Test split: test_size=0.3, random_state=21

# %%
# Görev-1

# %% [markdown]
# ### Görev-2 — Baseline (herkese ortalama)
# 1) `y_train.mean()` hesapla
# 2) Herkese bu değeri tahmin et
# 3) MAE ve RMSE yazdır (RMSE icin sqrt kullan)

# %%
# Görev-2

# %% [markdown]
# ### Görev-3 — Linear Regression Pipeline
# 1) Kategorik ve sayısal kolonları ayır
# 2) OneHotEncoder ile kategorikleri encode et
# 3) LinearRegression modeli kur ve eğit
# 4) MAE / RMSE / R2 yazdır

# %%
# Görev-3

# %% [markdown]
# ### Gorev-4 — Grafik: Actual vs Predicted
# 1) scatter ciz: x=actual, y=pred
# 2) (Bonus) y=x çizgisini ekle

# %%
# Görev-4


# y=x

# %% [markdown]
# ### Gorev-5 — Residual analizi
# 1) residual = actual - predicted
# 2) Predicted vs Residual scatter çiz ve y=0 çizgisi ekle
# 3) 1 cümle: residual'lar rastgele mi görünüyor?

# %%
# Görev-5



# Yorum: ...

# %% [markdown]
# ## Mini Rapor (6 madde) — En sona yaz
#
# Aşağıdaki 6 maddeyi **1-2 cümle** ile cevapla:
# 1) Baseline RMSE ve Model RMSE arasındaki fark ne?
# 2) R2 ne anlama geliyor? Senin modelinde kaç çıktı?
# 3) Actual vs Predicted grafiğinde noktalar diyagonale yakın mi? Ne demek bu?
# 4) Residual grafiğinde belirgin bir trend var mi? (var/yok)
# 5) En büyük absolute residual'a sahip 1 örnek bul ve yaz (actual/pred/residual).
# 6) Modeli geliştirmek icin 1 fikir yaz (or: daha fazla veri, başka model, yeni feature)
#
# > Cevaplarını buraya yaz:
# - 1) ...
# - 2) ...
# - 3) ...
# - 4) ...
# - 5) ...
# - 6) ...
