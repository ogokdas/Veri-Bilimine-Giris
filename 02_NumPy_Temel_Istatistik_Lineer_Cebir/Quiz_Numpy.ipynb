# %% [markdown]
# # NumPy Mini Test
#
# **Kural:** Her soruyu tek bir hücrede çözmeye çalış.
#
# > İpucu: Çoğu soru `shape`, `axis`, boolean mask, broadcasting ve basit istatistik üzerine.

# %% [markdown]
# ## S1) Array oluşturma + dtype
# - 1’den 10’a kadar (dahil) sayıları içeren bir NumPy array oluştur.
# - `dtype` değerini yazdır.

# %%
import numpy as np

a = None
print(a)
print(a.dtype)

# %% [markdown]
# ## S2) Reshape + shape
# - `a` dizisini **(2,5)** şekline getir ve `shape` yazdır.

# %%
A = None
print(A)
print(A.shape)

# %% [markdown]
# ## S3) Boolean mask ile filtreleme
# - `A` içindeki **5'ten büyük** değerleri seç (1D array olarak) ve yazdır.

# %%
filtered = None
print(filtered)

# %% [markdown]
# ## S4) Axis ile özetleme
# - `A` için **satır toplamlarını (axis=1)** hesapla ve yazdır.
# - `A` için **sütun ortalamalarını (axis=0)** hesapla ve yazdır.

# %%
row_sum = None
col_mean = None
print(row_sum)
print(col_mean)

# %% [markdown]
# ## S5) Broadcasting
# - `A` matrisinin her elemanına **10 ekle** ve sonucu yazdır.
# - `A` matrisinin her satırına sırasıyla **[0, 100]** ekle (satır bazlı) ve yazdır.

# %%
B1 = None
B2 = None
print(B1)
print(B2)

# %% [markdown]
# ## S6) Normalizasyon (min-max)
# - A'nın min-max normalize edilmiş halini hesapla:
#   A_norm  =  (A - A_min)  /  (A_max - A_min)
# - Sonucu yazdır.

# %%
A_norm = None
print(A_norm)

# %% [markdown]
# ## S7) Hızlı pratik: vektörize işlem
# - `x = np.arange(1, 100001)` oluştur.
# - `y = x**2 + 2*x + 1` hesapla.
# - `y`'nin ilk 5 değerini yazdır.

# %%
x = None
y = None
print(y[:5])
