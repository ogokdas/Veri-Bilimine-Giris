# %% [markdown]
# # Ödev — API (JSON) -> Pandas
#
# - API'den JSON veri çekme
# - Pandas DataFrame'e çevirme
# - 2-3 kısa kontrol / soru
#
# **Kapsam:**
# - `requests.get(...)`
# - `response.status_code`
# - `response.json()`
# - `pd.DataFrame(...)` ve/veya `pd.json_normalize(...)`

# %% [markdown]
# ## Kurulum

# %%
import requests
import pandas as pd

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 140)

print("Hazır!")

# %% [markdown]
# ## 1) ÖDEV — Sadece işlemi yaz

# %% [markdown]
# ### Görev-1 — API isteği at (GET)
# Aşağıdaki endpoint'i kullan:
#
# - `https://jsonplaceholder.typicode.com/users`
#
# 1) `requests.get(url)` ile istek at
# 2) `status_code` yazdır
# 3) `json()` ile veriyi al ve `data` değişkenine koy
#
# > Sadece gerekli satırları yaz.

# %%
# Görev-1
url = "https://jsonplaceholder.typicode.com/users"

# resp = ...
# print("Status:", ...)
# data = ...
# type(data), len(data)

# %% [markdown]
# ### Görev-2 — Pandas DataFrame'e çevir
# 1) `data` listesinden bir DataFrame oluştur (`df_users`)
# 2) `df_users.head()` göster
# 3) Kolonları yazdır (`df_users.columns`)

# %%
# Görev-2
# df_users = ...
# df_users.head()

# %% [markdown]
# ### Görev-3 — Nested JSON'ı düzleştir (address)
# Bu endpoint'te `address` nested (iç içe) bir alan.
#
# 1) `pd.json_normalize(data)` ile `df_flat` oluştur
# 2) Sadece şu kolonları göster:
# - name
# - username
# - email
# - address.city
# - address.geo.lat
# - address.geo.lng

# %%
# Görev-3
# df_flat = ...
# df_flat[["name","username","email","address.city","address.geo.lat","address.geo.lng"]].head()

# %% [markdown]
# ### Görev-4 — Basit filtre (tek satır)
# `address.city` içinde "Gwenborough" olanları filtrele ve sadece `name` ve `email` göster.

# %%
# Görev-4 (tek satir)
# df_flat[ ... ]

# %% [markdown]
# ## Kısa Sorular (markdown ile cevapla)
#
# 1) API'den veri çekmede `status_code` neden kontrol edilir?
# 2) `response.json()` ne tip bir veri döner? (genelde)
# 3) `pd.DataFrame(data)` ile `pd.json_normalize(data)` farkı nedir?
# 4) Internet yoksa (offline) bu ödev nasıl adapte edilir? 1 cumle.
#
# > Cevaplarını buraya yaz:
# - 1) ...
# - 2) ...
# - 3) ...
# - 4) ...
