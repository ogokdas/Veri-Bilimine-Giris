# %% [markdown]
# # Ödev — ML-9 (Train/Test + Leakage Mantığı) — Telco Churn
#
# **Hedef:** Churn tahmini (0/1)
# **Kapsam:** Train/Test, baseline, doğru pipeline, leakage örneği
# **Dataset:** `WA_Fn-UseC_-Telco-Customer-Churn.csv` (notebook ile aynı klasörde olmalı)

# %% [markdown]
# ## Kurulum

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 140)

print("Hazır!")

# %% [markdown]
# ## 1) Veriyi yükle (Telco)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()

# %% [markdown]
# ## 2) ÖDEV GÖREVLERİ

# %% [markdown]
# ### Görev-1 — Hedef (y) oluştur ve hızlı kontrol
# 1) `Churn_flag` oluştur (Yes->1, No->0)
# 2) `value_counts()` ile Churn dağılımını yazdır
# 3) `TotalCharges` sayısal değilse sayısala çevir (hata olursa 0 yap)

# %%
# Görev-1

# %% [markdown]
# ### Görev-2 — X / y ayır
# 1) X: `Churn`, `Churn_flag`, `customerID` kolonlarını çıkart
# 2) y: `Churn_flag`
# 3) Train/Test split yap (test_size=0.25, stratify=y)

# %%
# Görev-2

# %% [markdown]
# ### Görev-3 — Baseline
# Model kurmadan, herkese `Churn=0` de:
# - Accuracy
# - F1

# %%
# Görev-3

# %% [markdown]
# ### Görev-4 — Doğru pipeline (OneHot + StandardScaler + LogisticRegression)
# 1) Kategorik ve sayısal kolonları ayır
# 2) ColumnTransformer ile preprocessing kur
# 3) Pipeline içinde LogisticRegression eğit
# 4) Test'te Accuracy ve F1 yazdır

# %%
# Görev-4

# %% [markdown]
# ### Görev-5 — Confusion Matrix
# 1) Confusion matrix hesapla
# 2) `ConfusionMatrixDisplay` ile çizdir

# %%
# Görev-5

# %% [markdown]
# ## Mini Rapor (5 madde) — En sona yaz
#
# Aşağıdaki 5 maddeyi **1-2 cümle** ile cevapla (markdown olarak yazman yeterli):
# 1) Bu veri setinde churn oranı yaklaşık kaç?
# 2) Baseline (herkese churn=0) hangi metriklerde nasıl çıktı?
# 3) Modelin accuracy ve F1 değerleri ne? Baseline'a göre fark?
# 4) Confusion matrix'te en çok hangi hata var? (FP mi FN mi?)
# 5) En az 1 örnek satır seç: (y_true, y_pred) ve kısaca yorumla.
#
# > Cevaplarını buraya yaz:
# - 1) ...
# - 2) ...
# - 3) ...
# - 4) ...
# - 5) ...
