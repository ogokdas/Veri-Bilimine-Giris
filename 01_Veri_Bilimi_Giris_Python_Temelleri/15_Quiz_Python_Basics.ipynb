# %% [markdown]
# # Python Temelleri — Mini Test
#
# **Amaç:** Temel Python konularını (değişkenler, string, list, dict, set, tuple, boolean, if, döngü, fonksiyon) pratikle ölçmek.
#
# **Kurallar**
# - Her soruyu altındaki kod hücresinde çöz.
# - Çözüm sonunda `print()` ile sonucu göster.

# %% [markdown]
# ## Soru 1 — Numbers: Ortalama

# %% [markdown]
# Aşağıdaki notların ortalamasını hesaplayıp yazdırın: `70, 85, 90`

# %%
not1 = 70
not2 = 85
not3 = 90

# ortalama hesapla

# %% [markdown]
# ## Soru 2 — String: E-posta kullanıcı adı

# %% [markdown]
# `eposta = 'kullanici@mail.com'` içinden sadece kullanıcı adını yazdırın.

# %%
eposta = "kullanici@mail.com"

# kullanıcı adını çıkar

# %% [markdown]
# ## Soru 3 — List: Sepet toplamı

# %% [markdown]
# Aşağıdaki fiyat listesinin toplamını yazdırın: `[120, 55, 300, 80]`

# %%
fiyatlar = [120, 55, 300, 80]

# toplamı hesapla

# %% [markdown]
# ## Soru 4 — List + If: 100'den büyükleri seç

# %% [markdown]
# Aşağıdaki listedeki **100'den büyük** değerleri yeni bir listeye ekleyip yazdırın: `[10, 250, 60, 130, 99]`

# %%
sayilar = [10, 250, 60, 130, 99]

# 100'den büyükleri filtrele

# %% [markdown]
# ## Soru 5 — Dictionary: Sipariş toplamı

# %% [markdown]
# Bir sipariş sözlüğü var:
# ```python
# siparis = {"urun": "Kulaklık", "adet": 3, "birim_fiyat": 799.90}
# ```
# Toplam tutarı hesaplayıp yazdırın.

# %%
siparis = {"urun": "Kulaklık", "adet": 3, "birim_fiyat": 799.90}

# toplam tutarı hesapla

# %% [markdown]
# ## Soru 6 — Set: Tekrarlı listeyi benzersiz yap

# %% [markdown]
# Aşağıdaki listeden tekrarları kaldırıp benzersiz isimleri yazdırın: `['Ali','Ayşe','Ali','Mehmet','Ayşe']`

# %%
isimler = ["Ali", "Ayşe", "Ali", "Mehmet", "Ayşe"]

# benzersiz isimleri set ile bul

# %% [markdown]
# ## Soru 7 — Tuple: Unpacking

# %% [markdown]
# Bir ürün tuple'ı var:
# ```python
# urun = ("Laptop", 35000, 12)  # (ad, fiyat, stok)
# ```
# Bu tuple'ı 3 değişkene ayırıp ekrana yazdırın.

# %%
urun = ("Laptop", 35000, 12)

# unpacking yap

# %% [markdown]
# ## Soru 8 — Boolean + If: Kampanya kontrolü

# %% [markdown]
# Sepet tutarı 1000 TL ve üzeriyse `Kargo bedava`, değilse `Kargo ücretli` yazdırın.

# %%
sepet_tutari = 850

# if ile kontrol et

# %% [markdown]
# ## Soru 9 — Döngü (for): 1-20 arası çift sayıların toplamı

# %% [markdown]
# 1 ile 20 arasındaki çift sayıların toplamını hesaplayıp yazdırın.

# %%
toplam = 0

# for ile çiftleri topla

# %% [markdown]
# ## Soru 10 — Fonksiyon: KDV hesapla

# %% [markdown]
# `kdv_hesapla(fiyat, kdv_orani=0.20)` adında fonksiyon yazın.
# - KDV dahil fiyatı `return` etsin.
# - 850 TL için sonucu yazdırın.

# %%
def kdv_hesapla(fiyat, kdv_orani=0.20):
    pass

print(kdv_hesapla(850))

# %% [markdown]
# ## Soru 11 — Döngü (while): 5'ten geriye say

# %% [markdown]
# 5'ten başlayıp 1'e kadar geri sayıp yazdırın (`while` kullanın).

# %%
sayi = 5

# while ile geri say

# %% [markdown]
# ## Soru 12 — Mini: Enumerate ile numaralı liste

# %% [markdown]
# Aşağıdaki ürünleri 1'den başlayarak numaralı şekilde yazdırın:
# `['Laptop', 'Mouse', 'Klavye']`

# %%
urunler = ["Laptop", "Mouse", "Klavye"]

# enumerate ile yazdır

# %% [markdown]
# ### Bitti ✅
