# %% [markdown]
# # Ödev — ML / Classification + F1/Confusion
#
# **Hedef:** Churn (0/1)
# **Kapsam:** Confusion matrix, precision/recall/F1, threshold etkisi
# **Dataset:** `WA_Fn-UseC_-Telco-Customer-Churn.csv`

# %% [markdown]
# ## Kurulum

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 140)
sns.set_theme()

print("Hazır!")

# %% [markdown]
# ## 1) Veriyi yükle

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()

# %% [markdown]
# ## 2) ÖDEV GÖREVLERİ

# %% [markdown]
# ### Görev-1 — Hedef + düzeltmeler
# 1) `Churn_flag` oluştur
# 2) `TotalCharges` sayısal değilse sayısala çevir
# 3) `Churn_flag` oranını yazdır

# %%
# Görev-1

# %% [markdown]
# ### Görev-2 — X/y ve split
# 1) X'ten `Churn`, `Churn_flag`, `customerID` çıkart
# 2) Split: test_size=0.2, stratify=y, random_state=99

# %%
# Görev-2

# %% [markdown]
# ### Görev-3 — Pipeline + olasılık
# 1) Preprocess: numeric -> impute+scale, categorical -> impute+onehot
# 2) LogisticRegression eğit
# 3) Test için `proba = predict_proba(...)[:,1]` hesapla

# %%
# Görev-3

# %% [markdown]
# ### Görev-4 — Threshold=0.5 için metrikler + confusion matrix
# 1) pred = (proba >= 0.5)
# 2) precision/recall/f1 yazdır
# 3) confusion matrix çizdir

# %%
# Görev-4

# %% [markdown]
# ### Görev-5 — Threshold karşılaştırma (0.3 / 0.5 / 0.7)
# Bir tablo oluştur:
# - threshold, precision, recall, f1

# %%
# Görev-5

# %% [markdown]
# ### Görev-6 — Tahmin tablosu (ilk 12 satır)
# Bir tablo göster:
# - y_true, y_pred (th=0.5), proba_churn

# %%
# Görev-6

# %% [markdown]
# ## Mini Rapor (5 madde) — En sona yaz
#
# Aşağıdaki 5 maddeyi **1-2 cümle** ile cevapla:
# 1) Precision ve Recall farkı nedir? (kisa)
# 2) Threshold 0.3 -> 0.7 olunca Precision/Recall nasıl değisti?
# 3) Senin icin churn probleminde hangisi daha önemli olabilir (Precision mi Recall mu) ve neden?
# 4) Confusion matrix'te en çok hangi hata var? (FN mi FP mi?)
# 5) Tahmin tablosundan 1 örnek seç ve yorumla (proba + y_true/y_pred).
#
# > Cevaplarını buraya yaz:
# - 1) ...
# - 2) ...
# - 3) ...
# - 4) ...
# - 5) ...
